# %%
using ApproxFun,PyPlot
setplotter("PyPlot");
# Out:
# INFO: Loading help data...

# %% [markdown]
# # Piecewise function sampling

# %%
f = abs(Fun(sin,[-5,5]))
r = ApproxFun.sample(f,10000)
ApproxFun.plot(f/sum(f))                           # Requires Gadfly or PyPlot
PyPlot.plt.hist(r;normed=true,bins=[-5.:.1:5.]);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x117b68a10>)

# %% [markdown]
# # Jacobi singularity sampling

# %%
x=Fun(identity)
f = exp(x)*sqrt(1-x^2)
r = ApproxFun.sample(f,10000)
ApproxFun.plot(f/sum(f))                           # Requires Gadfly or PyPlot
PyPlot.plt.hist(r;normed=true,bins=[-1.:.05:1.]);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11a867390>)

# %%
x=Fun(identity)
f = exp(x)/sqrt(1-x^2)
r = ApproxFun.sample(f,10000)
ApproxFun.plot(f/sum(f))                           # Requires Gadfly or PyPlot
PyPlot.plt.hist(r;normed=true,bins=[-1.:.05:1.]);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11b8f7950>)

# %%
x=Fun(identity)
f = exp(x)*(1-x)^0.123*(1+x)^(-0.234)
r = ApproxFun.sample(f,10000)
ApproxFun.plot(f/sum(f))                           # Requires Gadfly or PyPlot
PyPlot.plt.hist(r;normed=true,bins=[-1.:.05:1.]);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11dc08ed0>)

# %% [markdown]
# # Heavy-tail sampling

# %%
f=Fun(x->(1+sech(x))/(1+x^2),[-Inf,Inf])
r=ApproxFun.sample(f,10000)

x=-15:.05:15
ApproxFun.plot(x,f/sum(f))
PyPlot.plt.hist(r,x;normed=true);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11cc41d50>)

# %%
f=Fun(x->exp(-x),[0,Inf])
# Out:
# `Ray{T<:Number}` has no method matching Ray{T<:Number}(::Float64, ::Float64, ::Bool)
# while loading In[31], in expression starting on line 1
#
#  in Ray at /Users/solver/.julia/v0.3/ApproxFun/src/Domains/Ray.jl:27
#  in Interval at /Users/solver/.julia/v0.3/ApproxFun/src/Domains/Interval.jl:24
#  in Fun at /Users/solver/.julia/v0.3/ApproxFun/src/Fun/constructors.jl:206
