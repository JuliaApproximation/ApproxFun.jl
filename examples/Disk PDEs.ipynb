# %%
#Requires PyPlot

using ApproxFun

# %% [markdown]
# # Laplace Equation $u_{xx} + u_{yy} = 0$

# %%
d=Disk()
u=[dirichlet(d),lap(d)]\Fun(z->real(exp(z)),Circle())

plot(pad(u,50,50)) # we pad to get a nice plot
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10dbcd090>)
# PyObject <mpl_toolkits.mplot3d.art3d.Poly3DCollection object at 0x10dbed350>

# %%
u[.1,.2]-real(exp(.1+.2im))
# Out:
# 0.0 + 1.3877787807814457e-17im

# %% [markdown]
# # Poisson equation $u_{xx} + u_{yy} = f(x,y)$

# %%
d=Disk()
f=Fun((x,y)->exp(-10(x+.2).^2-20(y-.1).^2),d) 
u=[dirichlet(d),lap(d)]\[0.,f]
plot(u)
# Out:
# INFO: Loading help data...
# Figure(PyObject <matplotlib.figure.Figure object at 0x112b692d0>)
# PyObject <mpl_toolkits.mplot3d.art3d.Poly3DCollection object at 0x112e9de10>

# %% [markdown]
# # Helmholtz $u_{xx} + u_{yy} + 100u=0$

# %%
d=Disk()

u=[dirichlet(d),lap(d)+100I]\1.0
plot(u)
# Out:
# INFO: Loading help data...
# Figure(PyObject <matplotlib.figure.Figure object at 0x11fa7d4d0>)
# PyObject <mpl_toolkits.mplot3d.art3d.Poly3DCollection object at 0x11fab0e10>

# %%
d=Disk()

u=[neumann(d),lap(d)+100I]\1.0
plot(u)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11fab0f10>)
# PyObject <mpl_toolkits.mplot3d.art3d.Poly3DCollection object at 0x11fb05bd0>

# %% [markdown]
# # Screened Poisson  $u_{xx} + u_{yy} - 100u = 0, \partial u(\partial d) = 1$

# %%
d=Disk()
u=[neumann(d),lap(d)-100.0I]\1.0
plot(u)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x120200f90>)
# PyObject <mpl_toolkits.mplot3d.art3d.Poly3DCollection object at 0x12021cb10>

# %% [markdown]
# # Laplacian squared $\Delta^2 u = 0$

# %%
d=Disk()

u=[dirichlet(d),neumann(d),lap(d)^2]\Fun(z->real(exp(z)),Circle())
plot(pad(u,50,50)) # we pad to get a nice plot
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10fdb2190>)
# PyObject <mpl_toolkits.mplot3d.art3d.Poly3DCollection object at 0x10fdd0c10>
